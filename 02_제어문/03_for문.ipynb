# %%
# for문의 기본 구조 

# for 변수 in 리스트(또는 튜플, 문자열):
#     수행할 문장1
#     수행할 문장2
#     ...

# %%
test_list = ["one", "two", "three"]

for li in test_list:
    print(li)
# Out:
# one
# two
# three

# %%
# 다양한 for문의 사용
a = [(1, 2), (3, 4), (5, 6)]
for i, j in a:
    print(f"{i} X {j} = {i*j}")
# Out:
# 1 X 2 = 2
# 3 X 4 = 12
# 5 X 6 = 30
