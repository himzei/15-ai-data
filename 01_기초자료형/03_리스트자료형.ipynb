# %%
# 리스트는 어떻게 만들고 사용할까? 
a = [] # a = list()
b = [1, 2, 3]
c = ["life", "is", "too", "short"]
d = [1, 2, "life", "is"]
e = [1, 2, ["life", "is"]]

# a = int("1")

# %%
# 리스트의 인덱싱과 슬라이싱

a = [1, 2, 3]
print(type(a))

print(a)
# Out:
# <class 'list'>
# [1, 2, 3]

# %%
print(a[0])
print(a[1])
print(a[2])
# Out:
# 1
# 2
# 3

# %%
a[0] + a[-1]
# Out:
# 4

# %%
a = ["1", "2", "3"]
a[0] + a[-1]
# Out:
# '13'

# %%
a = [1, 2, 3, ["a", "b", "c"]]
len(a)
# Out:
# 4

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
a[-1][1]
# Out:
# 'b'

# %%
a = [1, 2, ["a", "b", ["life", "is"]]]
len(a)
# Out:
# 3

# %%
a[2][2][0]
# Out:
# 'life'

# %%
# 리스트의 슬라이싱
a = [1, 2, 3, 4, 5]
print(a[0:3])
print(a[:3])
print(a[0:])
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3, 4, 5]

# %%
a = [1, 2, 3, ["a", "b", "c"], 4, 5]

a[3][0:2]
# Out:
# ['a', 'b']

# %%
# 리스트 연산하기 

a = [1, 2, 3]
b = [4, 5, 6]
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1, 2, 3]
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트의 수정과 삭제 
a = [1, 2, 3]
a[2] = 4
print(a)
# Out:
# [1, 2, 4]
